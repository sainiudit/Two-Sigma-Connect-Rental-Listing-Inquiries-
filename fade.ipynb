# %%
import os
import sys
import operator
import numpy as np
import pandas as pd
from scipy import sparse
import xgboost as xgb
import random
from sklearn import model_selection, preprocessing, ensemble
from sklearn.metrics import log_loss
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

from sklearn.feature_selection import SelectKBest, chi2
from sklearn import metrics, ensemble, linear_model, svm
from numpy import log, ones, array, zeros, mean, std, repeat
import numpy as np
import scipy.sparse as sp
import re
import csv
from textblob import TextBlob
from time import time


pd.options.display.max_columns=999
#input data
train_df=pd.read_json('../input/train.json')
test_df=pd.read_json('../input/test.json')

# %%
from sklearn.cluster import Birch
def cluster_latlon(n_clusters, data):  
    #split the data between "around NYC" and "other locations" basically our first two clusters 
    data_c=data[(data.longitude>-74.05)&(data.longitude<-73.75)&(data.latitude>40.4)&(data.latitude<40.9)]
    data_e=data[~(data.longitude>-74.05)&(data.longitude<-73.75)&(data.latitude>40.4)&(data.latitude<40.9)]
    #put it in matrix form
    coords=data_c.as_matrix(columns=['latitude', "longitude"])
    
    brc = Birch(branching_factor=100, n_clusters=n_clusters, threshold=0.01,compute_labels=True)

    brc.fit(coords)
    clusters=brc.predict(coords)
    data_c["cluster_"+str(n_clusters)]=clusters
    data_e["cluster_"+str(n_clusters)]=-1 #assign cluster label -1 for the non NYC listings 
    data=pd.concat([data_c,data_e])
    #plt.scatter(data_c["longitude"], data_c["latitude"], c=data_c["cluster_"+str(n_clusters)], s=10, linewidth=0.1)
    #plt.title(str(n_clusters)+" Neighbourhoods from clustering")
    #plt.show()
    return data 

traingpsclusters=cluster_latlon(200, train_df[['listing_id','latitude','longitude']])
traingpsclusters=traingpsclusters.drop(['latitude','longitude'],axis=1)

testgpsclusters=cluster_latlon(200, test_df[['listing_id','latitude','longitude']])
testgpsclusters=testgpsclusters.drop(['latitude','longitude'],axis=1)

train_df=pd.merge(train_df,traingpsclusters,on='listing_id',how='left')
test_df=pd.merge(test_df,testgpsclusters,on='listing_id',how='left')

clusters_price_map=dict(train_df.groupby(by="cluster_200")["price"].median())
train_df["price_comparison"]=train_df['price']-train_df["cluster_200"].map(clusters_price_map)

clusters_price_map=dict(test_df.groupby(by="cluster_200")["price"].median())
test_df["price_comparison"]=test_df['price']-test_df["cluster_200"].map(clusters_price_map)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
def create_binary_features(df):
    bows = {
        "dogs": ("dogs", "dog"),
        "cats": ("cats",),
        "nofee": ("no fee", "no-fee", "no  fee", "nofee", "no_fee"),
        "lowfee": ("reduced_fee", "low_fee", "reduced fee", "low fee"),
        "furnished": ("furnished",),
        "parquet": ("parquet", "hardwood"),
        "concierge": ("concierge", "doorman", "housekeep", "in_super"),
        "prewar": ("prewar", "pre_war", "pre war", "pre-war"),
        "laundry": ("laundry", "lndry"),
        "health": ("health", "gym", "fitness", "training"),
        "transport": ("train", "subway", "transport"),
        "parking": ("parking",),
        "utilities": ("utilities", "heat water", "water included")
    }

    def indicator(bow):
        return lambda s: int(any([x in s for x in bow]))

    features = df["features"].apply(lambda f: " ".join(f).lower())   # convert features to string
    featurelist=[]
    for key in bows:
        df["feature_" + key] = features.apply(indicator(bows[key]))
        featurelist.append("feature_" + key)
    return df,featurelist

# %%
train_df,featurelist=create_binary_features(train_df)
test_df,featurelist=create_binary_features(test_df)

# %%
#basic features
train_df["price_t"] =train_df["price"]/train_df["bedrooms"]
test_df["price_t"] = test_df["price"]/test_df["bedrooms"] 
train_df["room_sum"] = train_df["bedrooms"]+train_df["bathrooms"] 
test_df["room_sum"] = test_df["bedrooms"]+test_df["bathrooms"] 

# count of photos #
train_df["num_photos"] = train_df["photos"].apply(len)
test_df["num_photos"] = test_df["photos"].apply(len)

# count of "features" #
train_df["num_features"] = train_df["features"].apply(len)
test_df["num_features"] = test_df["features"].apply(len)

# count of words present in description column #
train_df["num_description_words"] = train_df["description"].apply(lambda x: len(x.split(" ")))
test_df["num_description_words"] = test_df["description"].apply(lambda x: len(x.split(" ")))

train_df['created'] = pd.to_datetime(train_df['created'])
train_df['date'] = train_df['created'].dt.date
train_df["year"] = train_df["created"].dt.year
train_df['month'] = train_df['created'].dt.month
train_df['day'] = train_df['created'].dt.day
train_df['hour'] = train_df['created'].dt.hour
train_df['weekday'] = train_df['created'].dt.weekday
train_df['week'] = train_df['created'].dt.week
train_df['quarter'] = train_df['created'].dt.quarter
train_df['weekend'] = ((train_df['weekday'] == 5) & (train_df['weekday'] == 6))
train_df['wd'] = ((train_df['weekday'] != 5) & (train_df['weekday'] != 6))

test_df['created'] = pd.to_datetime(test_df['created'])
test_df['date'] = test_df['created'].dt.date
test_df["year"] = test_df["created"].dt.year
test_df['month'] = test_df['created'].dt.month
test_df['day'] = test_df['created'].dt.day
test_df['hour'] = test_df['created'].dt.hour
test_df['weekday'] = test_df['created'].dt.weekday
test_df['week'] = test_df['created'].dt.week
test_df['quarter'] = test_df['created'].dt.quarter
test_df['weekend'] = ((test_df['weekday'] == 5) & (test_df['weekday'] == 6))
test_df['wd'] = ((test_df['weekday'] != 5) & (test_df['weekday'] != 6))

train_df = train_df.join(
                   train_df['description'].apply(
                       lambda x: TextBlob(x).sentiment.polarity).rename('sentiment'))

test_df = test_df.join(
                   test_df['description'].apply(
                       lambda x: TextBlob(x).sentiment.polarity).rename('sentiment'))

train_df["pos"] = train_df.longitude.round(3).astype(str) + '_' + train_df.latitude.round(3).astype(str)

vals = train_df['pos'].value_counts()
dvals = vals.to_dict()
train_df["density"] = train_df['pos'].apply(lambda x: dvals.get(x, vals.min()))

test_df["pos"] = test_df.longitude.round(3).astype(str) + '_' + test_df.latitude.round(3).astype(str)

vals = test_df['pos'].value_counts()
dvals = vals.to_dict()
test_df["density"] = test_df['pos'].apply(lambda x: dvals.get(x, vals.min()))

features_to_use=["price_comparison","density","sentiment","wd","weekend","quarter","week","weekday","hour","day","month","year","bathrooms", "bedrooms", "latitude", "longitude", "price","price_t","num_photos", "num_features", "num_description_words","listing_id"]

# %%
features_to_use=features_to_use+featurelist

# %%
def runXGB(train_X, train_y, test_X, test_y=None, feature_names=None, seed_val=0, num_rounds=1000):
    param = {}
    param['objective'] = 'multi:softprob'
    param['eta'] = 0.03
    param['max_depth'] = 6
    param['silent'] = 1
    param['num_class'] = 3
    param['eval_metric'] = "mlogloss"
    param['min_child_weight'] = 1
    param['subsample'] = 0.7
    param['colsample_bytree'] = 0.7
    param['seed'] = seed_val
    num_rounds = num_rounds

    plst = list(param.items())
    xgtrain = xgb.DMatrix(train_X, label=train_y)

    if test_y is not None:
        xgtest = xgb.DMatrix(test_X, label=test_y)
        watchlist = [ (xgtrain,'train'), (xgtest, 'test') ]
        model = xgb.train(plst, xgtrain, num_rounds, watchlist, early_stopping_rounds=20)
    else:
        xgtest = xgb.DMatrix(test_X)
        model = xgb.train(plst, xgtrain, num_rounds)

    pred_test_y = model.predict(xgtest)
    return pred_test_y, model

# %%
index=list(range(train_df.shape[0]))
random.shuffle(index)
a=[np.nan]*len(train_df)
b=[np.nan]*len(train_df)
c=[np.nan]*len(train_df)

for i in range(5):
    building_level={}
    for j in train_df['manager_id'].values:
        building_level[j]=[0,0,0]
    test_index=index[int((i*train_df.shape[0])/5):int(((i+1)*train_df.shape[0])/5)]
    train_index=list(set(index).difference(test_index))
    for j in train_index:
        temp=train_df.iloc[j]
        if temp['interest_level']=='low':
            building_level[temp['manager_id']][0]+=1
        if temp['interest_level']=='medium':
            building_level[temp['manager_id']][1]+=1
        if temp['interest_level']=='high':
            building_level[temp['manager_id']][2]+=1
    for j in test_index:
        temp=train_df.iloc[j]
        if sum(building_level[temp['manager_id']])!=0:
            a[j]=building_level[temp['manager_id']][0]*1.0/sum(building_level[temp['manager_id']])
            b[j]=building_level[temp['manager_id']][1]*1.0/sum(building_level[temp['manager_id']])
            c[j]=building_level[temp['manager_id']][2]*1.0/sum(building_level[temp['manager_id']])
train_df['manager_level_low']=a
train_df['manager_level_medium']=b
train_df['manager_level_high']=c



a=[]
b=[]
c=[]
building_level={}
for j in train_df['manager_id'].values:
    building_level[j]=[0,0,0]
for j in range(train_df.shape[0]):
    temp=train_df.iloc[j]
    if temp['interest_level']=='low':
        building_level[temp['manager_id']][0]+=1
    if temp['interest_level']=='medium':
        building_level[temp['manager_id']][1]+=1
    if temp['interest_level']=='high':
        building_level[temp['manager_id']][2]+=1

for i in test_df['manager_id'].values:
    if i not in building_level.keys():
        a.append(np.nan)
        b.append(np.nan)
        c.append(np.nan)
    else:
        a.append(building_level[i][0]*1.0/sum(building_level[i]))
        b.append(building_level[i][1]*1.0/sum(building_level[i]))
        c.append(building_level[i][2]*1.0/sum(building_level[i]))
test_df['manager_level_low']=a
test_df['manager_level_medium']=b
test_df['manager_level_high']=c

features_to_use.append('manager_level_low') 
features_to_use.append('manager_level_medium') 
features_to_use.append('manager_level_high')

# %%
categorical = ["display_address", "manager_id", "building_id", "street_address"]
for f in categorical:
        if train_df[f].dtype=='object':
            #print(f)
            lbl = preprocessing.LabelEncoder()
            lbl.fit(list(train_df[f].values) + list(test_df[f].values))
            train_df[f] = lbl.transform(list(train_df[f].values))
            test_df[f] = lbl.transform(list(test_df[f].values))
            features_to_use.append(f)

# %%
train_df['features'] = train_df["features"].apply(lambda x: " ".join(["_".join(i.split(" ")) for i in x]))
test_df['features'] = test_df["features"].apply(lambda x: " ".join(["_".join(i.split(" ")) for i in x]))
print(train_df["features"].head())
tfidf = CountVectorizer(stop_words='english', max_features=200)
tr_sparse = tfidf.fit_transform(train_df["features"])
te_sparse = tfidf.transform(test_df["features"])
# Out:
# 0
# 1    Doorman Elevator Fitness_Center Cats_Allowed D...
# 2    Laundry_In_Building Dishwasher Hardwood_Floors...
# 3                               Hardwood_Floors No_Fee
# 4                                              Pre-War
# Name: features, dtype: object

# %%
train_X = sparse.hstack([train_df[features_to_use], tr_sparse]).tocsr()
test_X = sparse.hstack([test_df[features_to_use], te_sparse]).tocsr()

target_num_map = {'high':0, 'medium':1, 'low':2}
train_y = np.array(train_df['interest_level'].apply(lambda x: target_num_map[x]))
print(train_X.shape, test_X.shape)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-76074f35fd05> in <module>()
# ----> 1 train_X = sparse.hstack([train_df[features_to_use], tr_sparse]).tocsr()
#       2 test_X = sparse.hstack([test_df[features_to_use], te_sparse]).tocsr()
#       3
#       4 target_num_map = {'high':0, 'medium':1, 'low':2}
#       5 train_y = np.array(train_df['interest_level'].apply(lambda x: target_num_map[x]))
#
# /usr/local/lib/python2.7/dist-packages/scipy/sparse/construct.pyc in hstack(blocks, format, dtype)
#     456
#     457     """
# --> 458     return bmat([blocks], format=format, dtype=dtype)
#     459
#     460
#
# /usr/local/lib/python2.7/dist-packages/scipy/sparse/construct.pyc in bmat(blocks, format, dtype)
#     592     if dtype is None:
#     593         all_dtypes = [blk.dtype for blk in blocks[block_mask]]
# --> 594         dtype = upcast(*all_dtypes) if all_dtypes else None
#     595
#     596     row_offsets = np.append(0, np.cumsum(brow_lengths))
#
# /usr/local/lib/python2.7/dist-packages/scipy/sparse/sputils.pyc in upcast(*args)
#      49             return t
#      50
# ---> 51     raise TypeError('no supported conversion for types: %r' % (args,))
#      52
#      53
#
# TypeError: no supported conversion for types: (dtype('O'), dtype('int64'))

# %%
cv_scores = []
kf = model_selection.KFold(n_splits=5, shuffle=True, random_state=2016)
for dev_index, val_index in kf.split(range(train_X.shape[0])):
        dev_X, val_X = train_X[dev_index,:], train_X[val_index,:]
        dev_y, val_y = train_y[dev_index], train_y[val_index]
        preds, model = runXGB(dev_X, dev_y, val_X, val_y)
        cv_scores.append(log_loss(val_y, preds))
        print(cv_scores)
        break
# Out:
# [0]	train-mlogloss:1.07869	test-mlogloss:1.07925
# Multiple eval metrics have been passed: 'test-mlogloss' will be used for early stopping.
#
# Will train until test-mlogloss hasn't improved in 20 rounds.
# [1]	train-mlogloss:1.05987	test-mlogloss:1.06086
# [2]	train-mlogloss:1.04192	test-mlogloss:1.04337
# [3]	train-mlogloss:1.02531	test-mlogloss:1.02716
# [4]	train-mlogloss:1.00982	test-mlogloss:1.01204
# [5]	train-mlogloss:0.993505	test-mlogloss:0.996167
# [6]	train-mlogloss:0.978509	test-mlogloss:0.98162
# [7]	train-mlogloss:0.964422	test-mlogloss:0.967811
# [8]	train-mlogloss:0.951805	test-mlogloss:0.955489
# [9]	train-mlogloss:0.938163	test-mlogloss:0.942257
# [10]	train-mlogloss:0.924776	test-mlogloss:0.929271
# [11]	train-mlogloss:0.913698	test-mlogloss:0.918534
# [12]	train-mlogloss:0.901448	test-mlogloss:0.906776
# [13]	train-mlogloss:0.890257	test-mlogloss:0.896035
# [14]	train-mlogloss:0.879363	test-mlogloss:0.885371
# [15]	train-mlogloss:0.869108	test-mlogloss:0.875485
# [16]	train-mlogloss:0.85851	test-mlogloss:0.865232
# [17]	train-mlogloss:0.849197	test-mlogloss:0.85614
# [18]	train-mlogloss:0.841264	test-mlogloss:0.848481
# [19]	train-mlogloss:0.832205	test-mlogloss:0.839725
# [20]	train-mlogloss:0.823538	test-mlogloss:0.831493
# [21]	train-mlogloss:0.814896	test-mlogloss:0.823168
# [22]	train-mlogloss:0.807659	test-mlogloss:0.816249
# [23]	train-mlogloss:0.800601	test-mlogloss:0.809397
# [24]	train-mlogloss:0.793184	test-mlogloss:0.802264
# [25]	train-mlogloss:0.785547	test-mlogloss:0.794982
# [26]	train-mlogloss:0.778558	test-mlogloss:0.788363
# [27]	train-mlogloss:0.772655	test-mlogloss:0.782688
# [28]	train-mlogloss:0.766647	test-mlogloss:0.776934
# [29]	train-mlogloss:0.760826	test-mlogloss:0.771347
# [30]	train-mlogloss:0.754926	test-mlogloss:0.765748
# [31]	train-mlogloss:0.749218	test-mlogloss:0.760304
# [32]	train-mlogloss:0.743076	test-mlogloss:0.754556
# [33]	train-mlogloss:0.738615	test-mlogloss:0.750316
# [34]	train-mlogloss:0.733189	test-mlogloss:0.745202
# [35]	train-mlogloss:0.727746	test-mlogloss:0.740147
# [36]	train-mlogloss:0.722689	test-mlogloss:0.735459
# [37]	train-mlogloss:0.718082	test-mlogloss:0.731108
# [38]	train-mlogloss:0.713352	test-mlogloss:0.726679
# [39]	train-mlogloss:0.708552	test-mlogloss:0.722277
# [40]	train-mlogloss:0.704116	test-mlogloss:0.718156
# [41]	train-mlogloss:0.69991	test-mlogloss:0.71435
# [42]	train-mlogloss:0.69602	test-mlogloss:0.710747
# [43]	train-mlogloss:0.691789	test-mlogloss:0.70684
# [44]	train-mlogloss:0.688274	test-mlogloss:0.703563
# [45]	train-mlogloss:0.684996	test-mlogloss:0.700535
# [46]	train-mlogloss:0.680943	test-mlogloss:0.696809
# [47]	train-mlogloss:0.677009	test-mlogloss:0.69317
# [48]	train-mlogloss:0.673403	test-mlogloss:0.689883
# [49]	train-mlogloss:0.670082	test-mlogloss:0.686877
# [50]	train-mlogloss:0.666568	test-mlogloss:0.683795
# [51]	train-mlogloss:0.663076	test-mlogloss:0.680603
# [52]	train-mlogloss:0.65979	test-mlogloss:0.67756
# [53]	train-mlogloss:0.656713	test-mlogloss:0.674814
# [54]	train-mlogloss:0.654758	test-mlogloss:0.673021
# [55]	train-mlogloss:0.651794	test-mlogloss:0.670335
# [56]	train-mlogloss:0.648739	test-mlogloss:0.667607
# [57]	train-mlogloss:0.64589	test-mlogloss:0.664979
# [58]	train-mlogloss:0.643136	test-mlogloss:0.662464
# [59]	train-mlogloss:0.64123	test-mlogloss:0.660763
# [60]	train-mlogloss:0.63863	test-mlogloss:0.658428
# [61]	train-mlogloss:0.636193	test-mlogloss:0.656214
# [62]	train-mlogloss:0.633886	test-mlogloss:0.654209
# [63]	train-mlogloss:0.631438	test-mlogloss:0.651962
# [64]	train-mlogloss:0.629029	test-mlogloss:0.64993
# [65]	train-mlogloss:0.627088	test-mlogloss:0.648224
# [66]	train-mlogloss:0.624722	test-mlogloss:0.646098
# [67]	train-mlogloss:0.62246	test-mlogloss:0.644098
# [68]	train-mlogloss:0.620381	test-mlogloss:0.642337
# [69]	train-mlogloss:0.618506	test-mlogloss:0.640739
# [70]	train-mlogloss:0.616507	test-mlogloss:0.638941
# [71]	train-mlogloss:0.614773	test-mlogloss:0.637396
# [72]	train-mlogloss:0.613416	test-mlogloss:0.636237
# [73]	train-mlogloss:0.611399	test-mlogloss:0.634521
# [74]	train-mlogloss:0.610322	test-mlogloss:0.633601
# [75]	train-mlogloss:0.608881	test-mlogloss:0.632344
# [76]	train-mlogloss:0.607087	test-mlogloss:0.63082
# [77]	train-mlogloss:0.605459	test-mlogloss:0.629409
# [78]	train-mlogloss:0.604059	test-mlogloss:0.628244
# [79]	train-mlogloss:0.602955	test-mlogloss:0.627334
# [80]	train-mlogloss:0.601698	test-mlogloss:0.626293
# [81]	train-mlogloss:0.600375	test-mlogloss:0.625209
# [82]	train-mlogloss:0.599471	test-mlogloss:0.624461
# [83]	train-mlogloss:0.597916	test-mlogloss:0.623147
# [84]	train-mlogloss:0.596289	test-mlogloss:0.62179
# [85]	train-mlogloss:0.594818	test-mlogloss:0.620589
# [86]	train-mlogloss:0.593589	test-mlogloss:0.61952
# [87]	train-mlogloss:0.592247	test-mlogloss:0.618393
# [88]	train-mlogloss:0.590974	test-mlogloss:0.617331
# [89]	train-mlogloss:0.589491	test-mlogloss:0.616138
# [90]	train-mlogloss:0.588076	test-mlogloss:0.614976
# [91]	train-mlogloss:0.586845	test-mlogloss:0.613944
# [92]	train-mlogloss:0.585592	test-mlogloss:0.612909
# [93]	train-mlogloss:0.584204	test-mlogloss:0.611795
# [94]	train-mlogloss:0.582801	test-mlogloss:0.610658
# [95]	train-mlogloss:0.58166	test-mlogloss:0.609787
# [96]	train-mlogloss:0.580742	test-mlogloss:0.608988
# [97]	train-mlogloss:0.579463	test-mlogloss:0.608031
# [98]	train-mlogloss:0.57841	test-mlogloss:0.607138
# [99]	train-mlogloss:0.577264	test-mlogloss:0.606241
# [100]	train-mlogloss:0.576525	test-mlogloss:0.605673
# [101]	train-mlogloss:0.57535	test-mlogloss:0.604704
# [102]	train-mlogloss:0.574253	test-mlogloss:0.603875
# [103]	train-mlogloss:0.573307	test-mlogloss:0.60316
# [104]	train-mlogloss:0.572227	test-mlogloss:0.602333
# [105]	train-mlogloss:0.571162	test-mlogloss:0.60152
# [106]	train-mlogloss:0.570233	test-mlogloss:0.600883
# [107]	train-mlogloss:0.569268	test-mlogloss:0.600137
# [108]	train-mlogloss:0.568306	test-mlogloss:0.599407
# [109]	train-mlogloss:0.56756	test-mlogloss:0.598786
# [110]	train-mlogloss:0.566652	test-mlogloss:0.598123
# [111]	train-mlogloss:0.565897	test-mlogloss:0.597538
# [112]	train-mlogloss:0.565087	test-mlogloss:0.596946
# [113]	train-mlogloss:0.564164	test-mlogloss:0.596318
# [114]	train-mlogloss:0.563367	test-mlogloss:0.595771
# [115]	train-mlogloss:0.562467	test-mlogloss:0.5951
# [116]	train-mlogloss:0.561551	test-mlogloss:0.594393
# [117]	train-mlogloss:0.560657	test-mlogloss:0.59367
# [118]	train-mlogloss:0.559872	test-mlogloss:0.593143
# [119]	train-mlogloss:0.559305	test-mlogloss:0.592723
# [120]	train-mlogloss:0.558468	test-mlogloss:0.592052
# [121]	train-mlogloss:0.557622	test-mlogloss:0.591499
# [122]	train-mlogloss:0.557086	test-mlogloss:0.591099
# [123]	train-mlogloss:0.556262	test-mlogloss:0.59047
# [124]	train-mlogloss:0.555582	test-mlogloss:0.590007
# [125]	train-mlogloss:0.554776	test-mlogloss:0.589439
# [126]	train-mlogloss:0.553903	test-mlogloss:0.58878
# [127]	train-mlogloss:0.55312	test-mlogloss:0.588156
# [128]	train-mlogloss:0.552332	test-mlogloss:0.587565
# [129]	train-mlogloss:0.551649	test-mlogloss:0.587062
# [130]	train-mlogloss:0.550996	test-mlogloss:0.586646
# [131]	train-mlogloss:0.550464	test-mlogloss:0.586269
# [132]	train-mlogloss:0.549789	test-mlogloss:0.585782
# [133]	train-mlogloss:0.549148	test-mlogloss:0.585328
# [134]	train-mlogloss:0.548317	test-mlogloss:0.584802
# [135]	train-mlogloss:0.547816	test-mlogloss:0.584503
# [136]	train-mlogloss:0.54717	test-mlogloss:0.584029
# [137]	train-mlogloss:0.546471	test-mlogloss:0.58361
# [138]	train-mlogloss:0.545743	test-mlogloss:0.583073
# [139]	train-mlogloss:0.545139	test-mlogloss:0.58266
# [140]	train-mlogloss:0.544419	test-mlogloss:0.582281
# [141]	train-mlogloss:0.54389	test-mlogloss:0.581901
# [142]	train-mlogloss:0.543175	test-mlogloss:0.581403
# [143]	train-mlogloss:0.54249	test-mlogloss:0.580933
# [144]	train-mlogloss:0.542055	test-mlogloss:0.58065
# [145]	train-mlogloss:0.54145	test-mlogloss:0.580279
# [146]	train-mlogloss:0.540914	test-mlogloss:0.579974
# [147]	train-mlogloss:0.540353	test-mlogloss:0.579629
# [148]	train-mlogloss:0.539759	test-mlogloss:0.57932
# [149]	train-mlogloss:0.539271	test-mlogloss:0.578958
# [150]	train-mlogloss:0.538842	test-mlogloss:0.578667
# [151]	train-mlogloss:0.538383	test-mlogloss:0.578395
# [152]	train-mlogloss:0.537826	test-mlogloss:0.578055
# [153]	train-mlogloss:0.537221	test-mlogloss:0.57776
# [154]	train-mlogloss:0.536517	test-mlogloss:0.577319
# [155]	train-mlogloss:0.536033	test-mlogloss:0.577076
# [156]	train-mlogloss:0.535506	test-mlogloss:0.576689
# [157]	train-mlogloss:0.534912	test-mlogloss:0.576315
# [158]	train-mlogloss:0.534454	test-mlogloss:0.576013
# [159]	train-mlogloss:0.533895	test-mlogloss:0.575682
# [160]	train-mlogloss:0.533339	test-mlogloss:0.575315
# [161]	train-mlogloss:0.532891	test-mlogloss:0.575006
# [162]	train-mlogloss:0.532379	test-mlogloss:0.574734
# [163]	train-mlogloss:0.531718	test-mlogloss:0.574387
# [164]	train-mlogloss:0.531221	test-mlogloss:0.574129
# [165]	train-mlogloss:0.530697	test-mlogloss:0.573855
# [166]	train-mlogloss:0.530168	test-mlogloss:0.573544
# [167]	train-mlogloss:0.529748	test-mlogloss:0.57331
# [168]	train-mlogloss:0.529369	test-mlogloss:0.573134
# [169]	train-mlogloss:0.529004	test-mlogloss:0.572876
# [170]	train-mlogloss:0.528507	test-mlogloss:0.572627
# [171]	train-mlogloss:0.527919	test-mlogloss:0.572302
# [172]	train-mlogloss:0.527567	test-mlogloss:0.572085
# [173]	train-mlogloss:0.527321	test-mlogloss:0.571918
# [174]	train-mlogloss:0.526801	test-mlogloss:0.571657
# [175]	train-mlogloss:0.526389	test-mlogloss:0.571409
# [176]	train-mlogloss:0.525927	test-mlogloss:0.571188
# [177]	train-mlogloss:0.525423	test-mlogloss:0.570944
# [178]	train-mlogloss:0.524813	test-mlogloss:0.570628
# [179]	train-mlogloss:0.524307	test-mlogloss:0.570398
# [180]	train-mlogloss:0.523884	test-mlogloss:0.570216
# [181]	train-mlogloss:0.52349	test-mlogloss:0.570045
# [182]	train-mlogloss:0.523039	test-mlogloss:0.569828
# [183]	train-mlogloss:0.522687	test-mlogloss:0.569646
# [184]	train-mlogloss:0.522243	test-mlogloss:0.569437
# [185]	train-mlogloss:0.521765	test-mlogloss:0.569248
# [186]	train-mlogloss:0.52135	test-mlogloss:0.569044
# [187]	train-mlogloss:0.520931	test-mlogloss:0.56882
# [188]	train-mlogloss:0.520532	test-mlogloss:0.568629
# [189]	train-mlogloss:0.520105	test-mlogloss:0.568457
# [190]	train-mlogloss:0.519643	test-mlogloss:0.568165
# [191]	train-mlogloss:0.519232	test-mlogloss:0.568003
# [192]	train-mlogloss:0.51878	test-mlogloss:0.567809
# [193]	train-mlogloss:0.518332	test-mlogloss:0.567525
# [194]	train-mlogloss:0.517807	test-mlogloss:0.567276
# [195]	train-mlogloss:0.517492	test-mlogloss:0.567143
# [196]	train-mlogloss:0.51712	test-mlogloss:0.566988
# [197]	train-mlogloss:0.516681	test-mlogloss:0.566752
# [198]	train-mlogloss:0.516317	test-mlogloss:0.566531
# [199]	train-mlogloss:0.51595	test-mlogloss:0.566412
# [200]	train-mlogloss:0.515511	test-mlogloss:0.56623
# [201]	train-mlogloss:0.515052	test-mlogloss:0.566002
# [202]	train-mlogloss:0.514627	test-mlogloss:0.565787
# [203]	train-mlogloss:0.514174	test-mlogloss:0.565549
# [204]	train-mlogloss:0.513693	test-mlogloss:0.565352
# [205]	train-mlogloss:0.513254	test-mlogloss:0.565128
# [206]	train-mlogloss:0.512924	test-mlogloss:0.56497
# [207]	train-mlogloss:0.512464	test-mlogloss:0.564794
# [208]	train-mlogloss:0.512129	test-mlogloss:0.564625
# [209]	train-mlogloss:0.511836	test-mlogloss:0.564502
# [210]	train-mlogloss:0.511634	test-mlogloss:0.564408
# [211]	train-mlogloss:0.511377	test-mlogloss:0.564285
# [212]	train-mlogloss:0.510877	test-mlogloss:0.564047
# [213]	train-mlogloss:0.510473	test-mlogloss:0.563868
# [214]	train-mlogloss:0.510169	test-mlogloss:0.563767
# [215]	train-mlogloss:0.509814	test-mlogloss:0.563666
# [216]	train-mlogloss:0.509429	test-mlogloss:0.56347
# [217]	train-mlogloss:0.509159	test-mlogloss:0.563345
# [218]	train-mlogloss:0.508845	test-mlogloss:0.563186
# [219]	train-mlogloss:0.508613	test-mlogloss:0.563043
# [220]	train-mlogloss:0.508331	test-mlogloss:0.562929
# [221]	train-mlogloss:0.507949	test-mlogloss:0.562758
# [222]	train-mlogloss:0.507608	test-mlogloss:0.562623
# [223]	train-mlogloss:0.507452	test-mlogloss:0.562537
# [224]	train-mlogloss:0.507114	test-mlogloss:0.562409
# [225]	train-mlogloss:0.506672	test-mlogloss:0.562224
# [226]	train-mlogloss:0.506324	test-mlogloss:0.562064
# [227]	train-mlogloss:0.506012	test-mlogloss:0.561898
# [228]	train-mlogloss:0.505635	test-mlogloss:0.561737
# [229]	train-mlogloss:0.505345	test-mlogloss:0.561637
# [230]	train-mlogloss:0.504953	test-mlogloss:0.561486
# [231]	train-mlogloss:0.504605	test-mlogloss:0.561314
# [232]	train-mlogloss:0.504341	test-mlogloss:0.5612
# [233]	train-mlogloss:0.504217	test-mlogloss:0.561134
# [234]	train-mlogloss:0.50366	test-mlogloss:0.560861
# [235]	train-mlogloss:0.503377	test-mlogloss:0.560744
# [236]	train-mlogloss:0.503032	test-mlogloss:0.560588
# [237]	train-mlogloss:0.502799	test-mlogloss:0.560471
# [238]	train-mlogloss:0.50237	test-mlogloss:0.560349
# [239]	train-mlogloss:0.502073	test-mlogloss:0.560219
# [240]	train-mlogloss:0.501717	test-mlogloss:0.560069
# [241]	train-mlogloss:0.501421	test-mlogloss:0.559946
# [242]	train-mlogloss:0.500977	test-mlogloss:0.559768
# [243]	train-mlogloss:0.500737	test-mlogloss:0.559723
# [244]	train-mlogloss:0.500437	test-mlogloss:0.559653
# [245]	train-mlogloss:0.500038	test-mlogloss:0.559444
# [246]	train-mlogloss:0.499757	test-mlogloss:0.559384
# [247]	train-mlogloss:0.499521	test-mlogloss:0.559307
# [248]	train-mlogloss:0.499332	test-mlogloss:0.559275
# [249]	train-mlogloss:0.498971	test-mlogloss:0.559094
# [250]	train-mlogloss:0.498587	test-mlogloss:0.558988
# [251]	train-mlogloss:0.498223	test-mlogloss:0.558871
# [252]	train-mlogloss:0.497883	test-mlogloss:0.558695
# [253]	train-mlogloss:0.497611	test-mlogloss:0.558598
# [254]	train-mlogloss:0.497269	test-mlogloss:0.558464
# [255]	train-mlogloss:0.496934	test-mlogloss:0.558312
# [256]	train-mlogloss:0.49673	test-mlogloss:0.558234
# [257]	train-mlogloss:0.496447	test-mlogloss:0.558149
# [258]	train-mlogloss:0.496144	test-mlogloss:0.557995
# [259]	train-mlogloss:0.495849	test-mlogloss:0.557872
# [260]	train-mlogloss:0.495566	test-mlogloss:0.557802
# [261]	train-mlogloss:0.495401	test-mlogloss:0.557769
# [262]	train-mlogloss:0.495041	test-mlogloss:0.557631
# [263]	train-mlogloss:0.494665	test-mlogloss:0.557499
# [264]	train-mlogloss:0.494487	test-mlogloss:0.557419
# [265]	train-mlogloss:0.494255	test-mlogloss:0.557304
# [266]	train-mlogloss:0.494044	test-mlogloss:0.557215
# [267]	train-mlogloss:0.493687	test-mlogloss:0.557068
# [268]	train-mlogloss:0.493561	test-mlogloss:0.55701
# [269]	train-mlogloss:0.493278	test-mlogloss:0.556912
# [270]	train-mlogloss:0.492936	test-mlogloss:0.556769
# [271]	train-mlogloss:0.492727	test-mlogloss:0.556743
# [272]	train-mlogloss:0.492446	test-mlogloss:0.556646
# [273]	train-mlogloss:0.492176	test-mlogloss:0.556592
# [274]	train-mlogloss:0.491864	test-mlogloss:0.556481
# [275]	train-mlogloss:0.491723	test-mlogloss:0.556445
# [276]	train-mlogloss:0.491328	test-mlogloss:0.556259
# [277]	train-mlogloss:0.491109	test-mlogloss:0.55618
# [278]	train-mlogloss:0.490784	test-mlogloss:0.556068
# [279]	train-mlogloss:0.490488	test-mlogloss:0.555923
# [280]	train-mlogloss:0.490288	test-mlogloss:0.555842
# [281]	train-mlogloss:0.489921	test-mlogloss:0.555709
# [282]	train-mlogloss:0.489716	test-mlogloss:0.555578
# [283]	train-mlogloss:0.489414	test-mlogloss:0.555453
# [284]	train-mlogloss:0.489081	test-mlogloss:0.555353
# [285]	train-mlogloss:0.488798	test-mlogloss:0.55522
# [286]	train-mlogloss:0.48853	test-mlogloss:0.55515
# [287]	train-mlogloss:0.488193	test-mlogloss:0.555029
# [288]	train-mlogloss:0.487912	test-mlogloss:0.554939
# [289]	train-mlogloss:0.487624	test-mlogloss:0.554846
# [290]	train-mlogloss:0.487357	test-mlogloss:0.554763
# [291]	train-mlogloss:0.487083	test-mlogloss:0.554628
# [292]	train-mlogloss:0.48683	test-mlogloss:0.554537
# [293]	train-mlogloss:0.486475	test-mlogloss:0.554429
# [294]	train-mlogloss:0.486259	test-mlogloss:0.554349
# [295]	train-mlogloss:0.485938	test-mlogloss:0.554212
# [296]	train-mlogloss:0.485671	test-mlogloss:0.554103
# [297]	train-mlogloss:0.485473	test-mlogloss:0.554003
# [298]	train-mlogloss:0.485354	test-mlogloss:0.553968
# [299]	train-mlogloss:0.48505	test-mlogloss:0.553882
# [300]	train-mlogloss:0.484664	test-mlogloss:0.553718
# [301]	train-mlogloss:0.484278	test-mlogloss:0.553563
# [302]	train-mlogloss:0.483966	test-mlogloss:0.553495
# [303]	train-mlogloss:0.483666	test-mlogloss:0.553406
# [304]	train-mlogloss:0.483351	test-mlogloss:0.553273
# [305]	train-mlogloss:0.483162	test-mlogloss:0.553165
# [306]	train-mlogloss:0.482897	test-mlogloss:0.553132
# [307]	train-mlogloss:0.482664	test-mlogloss:0.553066
# [308]	train-mlogloss:0.482406	test-mlogloss:0.553002
# [309]	train-mlogloss:0.482199	test-mlogloss:0.552921
# [310]	train-mlogloss:0.481977	test-mlogloss:0.552842
# [311]	train-mlogloss:0.481688	test-mlogloss:0.552764
# [312]	train-mlogloss:0.481501	test-mlogloss:0.55268
# [313]	train-mlogloss:0.481249	test-mlogloss:0.552596
# [314]	train-mlogloss:0.480963	test-mlogloss:0.552495
# [315]	train-mlogloss:0.480802	test-mlogloss:0.55245
# [316]	train-mlogloss:0.480692	test-mlogloss:0.552381
# [317]	train-mlogloss:0.480426	test-mlogloss:0.552271
# [318]	train-mlogloss:0.480271	test-mlogloss:0.552222
# [319]	train-mlogloss:0.480024	test-mlogloss:0.552115
# [320]	train-mlogloss:0.479777	test-mlogloss:0.552016
# [321]	train-mlogloss:0.479421	test-mlogloss:0.551869
# [322]	train-mlogloss:0.479352	test-mlogloss:0.551853
# [323]	train-mlogloss:0.479033	test-mlogloss:0.551751
# [324]	train-mlogloss:0.478824	test-mlogloss:0.551663
# [325]	train-mlogloss:0.478557	test-mlogloss:0.551535
# [326]	train-mlogloss:0.478452	test-mlogloss:0.551476
# [327]	train-mlogloss:0.478137	test-mlogloss:0.551397
# [328]	train-mlogloss:0.477832	test-mlogloss:0.551262
# [329]	train-mlogloss:0.477603	test-mlogloss:0.551144
# [330]	train-mlogloss:0.477385	test-mlogloss:0.551112
# [331]	train-mlogloss:0.477066	test-mlogloss:0.551052
# [332]	train-mlogloss:0.476824	test-mlogloss:0.551
# [333]	train-mlogloss:0.476707	test-mlogloss:0.550941
# [334]	train-mlogloss:0.476523	test-mlogloss:0.550892
# [335]	train-mlogloss:0.476257	test-mlogloss:0.550856
# [336]	train-mlogloss:0.475954	test-mlogloss:0.550789
# [337]	train-mlogloss:0.475715	test-mlogloss:0.550753
# [338]	train-mlogloss:0.475479	test-mlogloss:0.550668
# [339]	train-mlogloss:0.475276	test-mlogloss:0.550626
# [340]	train-mlogloss:0.475064	test-mlogloss:0.550568
# [341]	train-mlogloss:0.474853	test-mlogloss:0.550488
# [342]	train-mlogloss:0.47479	test-mlogloss:0.550483
# [343]	train-mlogloss:0.474566	test-mlogloss:0.550393
# [344]	train-mlogloss:0.474341	test-mlogloss:0.550312
# [345]	train-mlogloss:0.474077	test-mlogloss:0.550222
# [346]	train-mlogloss:0.473808	test-mlogloss:0.550179
# [347]	train-mlogloss:0.473577	test-mlogloss:0.550114
# [348]	train-mlogloss:0.473424	test-mlogloss:0.550056
# [349]	train-mlogloss:0.473209	test-mlogloss:0.549971
# [350]	train-mlogloss:0.473024	test-mlogloss:0.54993
# [351]	train-mlogloss:0.472811	test-mlogloss:0.549871
# [352]	train-mlogloss:0.472539	test-mlogloss:0.549776
# [353]	train-mlogloss:0.472411	test-mlogloss:0.549741
# [354]	train-mlogloss:0.472265	test-mlogloss:0.549698
# [355]	train-mlogloss:0.47201	test-mlogloss:0.549612
# [356]	train-mlogloss:0.471704	test-mlogloss:0.549544
# [357]	train-mlogloss:0.471466	test-mlogloss:0.549516
# [358]	train-mlogloss:0.471296	test-mlogloss:0.54951
# [359]	train-mlogloss:0.471088	test-mlogloss:0.549447
# [360]	train-mlogloss:0.470869	test-mlogloss:0.549374
# [361]	train-mlogloss:0.470646	test-mlogloss:0.549295
# [362]	train-mlogloss:0.470416	test-mlogloss:0.549279
# [363]	train-mlogloss:0.470125	test-mlogloss:0.549175
# [364]	train-mlogloss:0.469895	test-mlogloss:0.549098
# [365]	train-mlogloss:0.469708	test-mlogloss:0.549028
# [366]	train-mlogloss:0.469494	test-mlogloss:0.548963
# [367]	train-mlogloss:0.469277	test-mlogloss:0.54895
# [368]	train-mlogloss:0.469039	test-mlogloss:0.548847
# [369]	train-mlogloss:0.46872	test-mlogloss:0.548726
# [370]	train-mlogloss:0.468539	test-mlogloss:0.548673
# [371]	train-mlogloss:0.468264	test-mlogloss:0.548612
# [372]	train-mlogloss:0.468049	test-mlogloss:0.548549
# [373]	train-mlogloss:0.467816	test-mlogloss:0.548486
# [374]	train-mlogloss:0.467464	test-mlogloss:0.54839
# [375]	train-mlogloss:0.467207	test-mlogloss:0.548375
# [376]	train-mlogloss:0.467056	test-mlogloss:0.548283
# [377]	train-mlogloss:0.466819	test-mlogloss:0.548193
# [378]	train-mlogloss:0.466628	test-mlogloss:0.548194
# [379]	train-mlogloss:0.466331	test-mlogloss:0.548132
# [380]	train-mlogloss:0.466106	test-mlogloss:0.548105
# [381]	train-mlogloss:0.465981	test-mlogloss:0.548053
# [382]	train-mlogloss:0.465678	test-mlogloss:0.548078
# [383]	train-mlogloss:0.465534	test-mlogloss:0.548036
# [384]	train-mlogloss:0.465385	test-mlogloss:0.54798
# [385]	train-mlogloss:0.465281	test-mlogloss:0.547969
# [386]	train-mlogloss:0.465046	test-mlogloss:0.547981
# [387]	train-mlogloss:0.464823	test-mlogloss:0.547914
# [388]	train-mlogloss:0.464617	test-mlogloss:0.547864
# [389]	train-mlogloss:0.464444	test-mlogloss:0.54783
# [390]	train-mlogloss:0.464246	test-mlogloss:0.547819
# [391]	train-mlogloss:0.464072	test-mlogloss:0.547778
# [392]	train-mlogloss:0.463828	test-mlogloss:0.54772
# [393]	train-mlogloss:0.463638	test-mlogloss:0.547642
# [394]	train-mlogloss:0.463378	test-mlogloss:0.547594
# [395]	train-mlogloss:0.463035	test-mlogloss:0.547518
# [396]	train-mlogloss:0.462741	test-mlogloss:0.547484
# [397]	train-mlogloss:0.462493	test-mlogloss:0.547424
# [398]	train-mlogloss:0.462267	test-mlogloss:0.547362
# [399]	train-mlogloss:0.462086	test-mlogloss:0.547322
# [400]	train-mlogloss:0.461761	test-mlogloss:0.547245
# [401]	train-mlogloss:0.461641	test-mlogloss:0.547246
# [402]	train-mlogloss:0.461433	test-mlogloss:0.547185
# [403]	train-mlogloss:0.461231	test-mlogloss:0.547154
# [404]	train-mlogloss:0.461036	test-mlogloss:0.547087
# [405]	train-mlogloss:0.46078	test-mlogloss:0.547029
# [406]	train-mlogloss:0.460505	test-mlogloss:0.546986
# [407]	train-mlogloss:0.460272	test-mlogloss:0.546932
# [408]	train-mlogloss:0.460093	test-mlogloss:0.546907
# [409]	train-mlogloss:0.459857	test-mlogloss:0.546876
# [410]	train-mlogloss:0.459642	test-mlogloss:0.546884
# [411]	train-mlogloss:0.45943	test-mlogloss:0.546862
# [412]	train-mlogloss:0.459288	test-mlogloss:0.546813
# [413]	train-mlogloss:0.459099	test-mlogloss:0.546771
# [414]	train-mlogloss:0.458922	test-mlogloss:0.54674
# [415]	train-mlogloss:0.458707	test-mlogloss:0.546697
# [416]	train-mlogloss:0.458439	test-mlogloss:0.546609
# [417]	train-mlogloss:0.458248	test-mlogloss:0.546543
# [418]	train-mlogloss:0.457972	test-mlogloss:0.546416
# [419]	train-mlogloss:0.457754	test-mlogloss:0.546353
# [420]	train-mlogloss:0.457573	test-mlogloss:0.546308
# [421]	train-mlogloss:0.457356	test-mlogloss:0.54621
# [422]	train-mlogloss:0.457193	test-mlogloss:0.546162
# [423]	train-mlogloss:0.456912	test-mlogloss:0.546036
# [424]	train-mlogloss:0.456724	test-mlogloss:0.546023
# [425]	train-mlogloss:0.456521	test-mlogloss:0.545953
# [426]	train-mlogloss:0.456293	test-mlogloss:0.545943
# [427]	train-mlogloss:0.456025	test-mlogloss:0.545903
# [428]	train-mlogloss:0.455752	test-mlogloss:0.54584
# [429]	train-mlogloss:0.455539	test-mlogloss:0.545747
# [430]	train-mlogloss:0.455335	test-mlogloss:0.545653
# [431]	train-mlogloss:0.455152	test-mlogloss:0.545587
# [432]	train-mlogloss:0.454979	test-mlogloss:0.545545
# [433]	train-mlogloss:0.454777	test-mlogloss:0.545522
# [434]	train-mlogloss:0.454481	test-mlogloss:0.545439
# [435]	train-mlogloss:0.454266	test-mlogloss:0.545383
# [436]	train-mlogloss:0.454044	test-mlogloss:0.545338
# [437]	train-mlogloss:0.453789	test-mlogloss:0.545269
# [438]	train-mlogloss:0.4536	test-mlogloss:0.545218
# [439]	train-mlogloss:0.453351	test-mlogloss:0.545185
# [440]	train-mlogloss:0.453179	test-mlogloss:0.545171
# [441]	train-mlogloss:0.452973	test-mlogloss:0.545097
# [442]	train-mlogloss:0.452776	test-mlogloss:0.545044
# [443]	train-mlogloss:0.452553	test-mlogloss:0.545026
# [444]	train-mlogloss:0.452319	test-mlogloss:0.544979
# [445]	train-mlogloss:0.452144	test-mlogloss:0.544964
# [446]	train-mlogloss:0.451969	test-mlogloss:0.544882
# [447]	train-mlogloss:0.451744	test-mlogloss:0.54483
# [448]	train-mlogloss:0.451574	test-mlogloss:0.544816
# [449]	train-mlogloss:0.451496	test-mlogloss:0.544792
# [450]	train-mlogloss:0.451319	test-mlogloss:0.54477
# [451]	train-mlogloss:0.451085	test-mlogloss:0.544771
# [452]	train-mlogloss:0.450872	test-mlogloss:0.54473
# [453]	train-mlogloss:0.450661	test-mlogloss:0.544705
# [454]	train-mlogloss:0.450473	test-mlogloss:0.544677
# [455]	train-mlogloss:0.450239	test-mlogloss:0.544629
# [456]	train-mlogloss:0.450043	test-mlogloss:0.54461
# [457]	train-mlogloss:0.449945	test-mlogloss:0.544604
# [458]	train-mlogloss:0.449724	test-mlogloss:0.544503
# [459]	train-mlogloss:0.449513	test-mlogloss:0.544453
# [460]	train-mlogloss:0.449425	test-mlogloss:0.544445
# [461]	train-mlogloss:0.449302	test-mlogloss:0.544445
# [462]	train-mlogloss:0.449109	test-mlogloss:0.544442
# [463]	train-mlogloss:0.448874	test-mlogloss:0.544411
# [464]	train-mlogloss:0.448825	test-mlogloss:0.544398
# [465]	train-mlogloss:0.448666	test-mlogloss:0.544388
# [466]	train-mlogloss:0.448468	test-mlogloss:0.544347
# [467]	train-mlogloss:0.448275	test-mlogloss:0.544321
# [468]	train-mlogloss:0.448018	test-mlogloss:0.544249
# [469]	train-mlogloss:0.447857	test-mlogloss:0.54423
# [470]	train-mlogloss:0.447689	test-mlogloss:0.544195
# [471]	train-mlogloss:0.447439	test-mlogloss:0.544145
# [472]	train-mlogloss:0.447286	test-mlogloss:0.544093
# [473]	train-mlogloss:0.447152	test-mlogloss:0.544057
# [474]	train-mlogloss:0.446955	test-mlogloss:0.544046
# [475]	train-mlogloss:0.446733	test-mlogloss:0.544025
# [476]	train-mlogloss:0.446497	test-mlogloss:0.543938
# [477]	train-mlogloss:0.446393	test-mlogloss:0.543918
# [478]	train-mlogloss:0.446189	test-mlogloss:0.543876
# [479]	train-mlogloss:0.445981	test-mlogloss:0.543817
# [480]	train-mlogloss:0.445729	test-mlogloss:0.543721
# [481]	train-mlogloss:0.445531	test-mlogloss:0.54369
# [482]	train-mlogloss:0.4453	test-mlogloss:0.543617
# [483]	train-mlogloss:0.445116	test-mlogloss:0.543523
# [484]	train-mlogloss:0.444889	test-mlogloss:0.543508
# [485]	train-mlogloss:0.444656	test-mlogloss:0.543477
# [486]	train-mlogloss:0.44448	test-mlogloss:0.543438
# [487]	train-mlogloss:0.444282	test-mlogloss:0.543399
# [488]	train-mlogloss:0.444013	test-mlogloss:0.543344
# [489]	train-mlogloss:0.443782	test-mlogloss:0.543277
# [490]	train-mlogloss:0.443574	test-mlogloss:0.543282
# [491]	train-mlogloss:0.443456	test-mlogloss:0.543264
# [492]	train-mlogloss:0.4433	test-mlogloss:0.543255
# [493]	train-mlogloss:0.443204	test-mlogloss:0.543234
# [494]	train-mlogloss:0.442964	test-mlogloss:0.543117
# [495]	train-mlogloss:0.442824	test-mlogloss:0.543084
# [496]	train-mlogloss:0.442672	test-mlogloss:0.543045
# [497]	train-mlogloss:0.442594	test-mlogloss:0.543025
# [498]	train-mlogloss:0.442329	test-mlogloss:0.542985
# [499]	train-mlogloss:0.4421	test-mlogloss:0.542927
# [500]	train-mlogloss:0.441887	test-mlogloss:0.542911
# [501]	train-mlogloss:0.441765	test-mlogloss:0.542881
# [502]	train-mlogloss:0.441624	test-mlogloss:0.542846
# [503]	train-mlogloss:0.441444	test-mlogloss:0.542831
# [504]	train-mlogloss:0.441257	test-mlogloss:0.542806
# [505]	train-mlogloss:0.441099	test-mlogloss:0.542775
# [506]	train-mlogloss:0.440915	test-mlogloss:0.542739
# [507]	train-mlogloss:0.440753	test-mlogloss:0.542698
# [508]	train-mlogloss:0.440546	test-mlogloss:0.542642
# [509]	train-mlogloss:0.440311	test-mlogloss:0.542596
# [510]	train-mlogloss:0.4402	test-mlogloss:0.542588
# [511]	train-mlogloss:0.440032	test-mlogloss:0.542554
# [512]	train-mlogloss:0.439865	test-mlogloss:0.542548
# [513]	train-mlogloss:0.439689	test-mlogloss:0.54253
# [514]	train-mlogloss:0.439447	test-mlogloss:0.542467
# [515]	train-mlogloss:0.439248	test-mlogloss:0.542427
# [516]	train-mlogloss:0.439031	test-mlogloss:0.542377
# [517]	train-mlogloss:0.438834	test-mlogloss:0.542341
# [518]	train-mlogloss:0.438654	test-mlogloss:0.542308
# [519]	train-mlogloss:0.438487	test-mlogloss:0.542271
# [520]	train-mlogloss:0.438291	test-mlogloss:0.542229
# [521]	train-mlogloss:0.438153	test-mlogloss:0.542191
# [522]	train-mlogloss:0.437895	test-mlogloss:0.542161
# [523]	train-mlogloss:0.437742	test-mlogloss:0.542117
# [524]	train-mlogloss:0.437599	test-mlogloss:0.542069
# [525]	train-mlogloss:0.437433	test-mlogloss:0.542053
# [526]	train-mlogloss:0.437213	test-mlogloss:0.542022
# [527]	train-mlogloss:0.437037	test-mlogloss:0.541967
# [528]	train-mlogloss:0.436878	test-mlogloss:0.541932
# [529]	train-mlogloss:0.436715	test-mlogloss:0.54189
# [530]	train-mlogloss:0.436582	test-mlogloss:0.541842
# [531]	train-mlogloss:0.436401	test-mlogloss:0.541798
# [532]	train-mlogloss:0.436182	test-mlogloss:0.541765
# [533]	train-mlogloss:0.436024	test-mlogloss:0.541722
# [534]	train-mlogloss:0.435867	test-mlogloss:0.541664
# [535]	train-mlogloss:0.435661	test-mlogloss:0.541595
# [536]	train-mlogloss:0.435477	test-mlogloss:0.541561
# [537]	train-mlogloss:0.435336	test-mlogloss:0.541551
# [538]	train-mlogloss:0.43513	test-mlogloss:0.541562
# [539]	train-mlogloss:0.43499	test-mlogloss:0.541522
# [540]	train-mlogloss:0.434747	test-mlogloss:0.54148
# [541]	train-mlogloss:0.434546	test-mlogloss:0.541468
# [542]	train-mlogloss:0.434395	test-mlogloss:0.541407
# [543]	train-mlogloss:0.434219	test-mlogloss:0.541382
# [544]	train-mlogloss:0.434181	test-mlogloss:0.54136
# [545]	train-mlogloss:0.433885	test-mlogloss:0.541321
# [546]	train-mlogloss:0.433703	test-mlogloss:0.541285
# [547]	train-mlogloss:0.433481	test-mlogloss:0.541238
# [548]	train-mlogloss:0.433268	test-mlogloss:0.541189
# [549]	train-mlogloss:0.433118	test-mlogloss:0.541158
# [550]	train-mlogloss:0.432946	test-mlogloss:0.541105
# [551]	train-mlogloss:0.432895	test-mlogloss:0.541097
# [552]	train-mlogloss:0.43263	test-mlogloss:0.54103
# [553]	train-mlogloss:0.432508	test-mlogloss:0.541006
# [554]	train-mlogloss:0.432339	test-mlogloss:0.540998
# [555]	train-mlogloss:0.432124	test-mlogloss:0.540942
# [556]	train-mlogloss:0.431961	test-mlogloss:0.540951
# [557]	train-mlogloss:0.431713	test-mlogloss:0.540878
# [558]	train-mlogloss:0.431516	test-mlogloss:0.540848
# [559]	train-mlogloss:0.431294	test-mlogloss:0.540852
# [560]	train-mlogloss:0.431172	test-mlogloss:0.540821
# [561]	train-mlogloss:0.430934	test-mlogloss:0.540744
# [562]	train-mlogloss:0.430725	test-mlogloss:0.540688
# [563]	train-mlogloss:0.43053	test-mlogloss:0.540655
# [564]	train-mlogloss:0.430366	test-mlogloss:0.54062
# [565]	train-mlogloss:0.43015	test-mlogloss:0.540572
# [566]	train-mlogloss:0.429995	test-mlogloss:0.540571
# [567]	train-mlogloss:0.429777	test-mlogloss:0.540557
# [568]	train-mlogloss:0.429631	test-mlogloss:0.540542
# [569]	train-mlogloss:0.429447	test-mlogloss:0.540514
# [570]	train-mlogloss:0.429301	test-mlogloss:0.540514
# [571]	train-mlogloss:0.429166	test-mlogloss:0.540512
# [572]	train-mlogloss:0.428981	test-mlogloss:0.540466
# [573]	train-mlogloss:0.428804	test-mlogloss:0.540409
# [574]	train-mlogloss:0.428639	test-mlogloss:0.54039
# [575]	train-mlogloss:0.428461	test-mlogloss:0.54036
# [576]	train-mlogloss:0.428349	test-mlogloss:0.540348
# [577]	train-mlogloss:0.428141	test-mlogloss:0.540332
# [578]	train-mlogloss:0.427958	test-mlogloss:0.540281
# [579]	train-mlogloss:0.427797	test-mlogloss:0.540276
# [580]	train-mlogloss:0.427581	test-mlogloss:0.540236
# [581]	train-mlogloss:0.427475	test-mlogloss:0.540223
# [582]	train-mlogloss:0.427291	test-mlogloss:0.540204
# [583]	train-mlogloss:0.427128	test-mlogloss:0.540201
# [584]	train-mlogloss:0.426901	test-mlogloss:0.540162
# [585]	train-mlogloss:0.426706	test-mlogloss:0.540133
# [586]	train-mlogloss:0.426522	test-mlogloss:0.540071
# [587]	train-mlogloss:0.426341	test-mlogloss:0.540082
# [588]	train-mlogloss:0.426229	test-mlogloss:0.540078
# [589]	train-mlogloss:0.426061	test-mlogloss:0.540055
# [590]	train-mlogloss:0.425868	test-mlogloss:0.540005
# [591]	train-mlogloss:0.425726	test-mlogloss:0.539975
# [592]	train-mlogloss:0.425563	test-mlogloss:0.539972
# [593]	train-mlogloss:0.425455	test-mlogloss:0.539972
# [594]	train-mlogloss:0.425296	test-mlogloss:0.539946
# [595]	train-mlogloss:0.425136	test-mlogloss:0.53994
# [596]	train-mlogloss:0.425057	test-mlogloss:0.539936
# [597]	train-mlogloss:0.424889	test-mlogloss:0.539955
# [598]	train-mlogloss:0.424798	test-mlogloss:0.539944
# [599]	train-mlogloss:0.424598	test-mlogloss:0.539886
# [600]	train-mlogloss:0.424418	test-mlogloss:0.539889
# [601]	train-mlogloss:0.424303	test-mlogloss:0.539891
# [602]	train-mlogloss:0.424117	test-mlogloss:0.539855
# [603]	train-mlogloss:0.423928	test-mlogloss:0.539828
# [604]	train-mlogloss:0.423765	test-mlogloss:0.539753
# [605]	train-mlogloss:0.423656	test-mlogloss:0.539752
# [606]	train-mlogloss:0.423529	test-mlogloss:0.539715
# [607]	train-mlogloss:0.42335	test-mlogloss:0.539693
# [608]	train-mlogloss:0.423128	test-mlogloss:0.539682
# [609]	train-mlogloss:0.422961	test-mlogloss:0.539655
# [610]	train-mlogloss:0.422749	test-mlogloss:0.539641
# [611]	train-mlogloss:0.422576	test-mlogloss:0.539612
# [612]	train-mlogloss:0.422312	test-mlogloss:0.539602
# [613]	train-mlogloss:0.422132	test-mlogloss:0.539559
# [614]	train-mlogloss:0.422001	test-mlogloss:0.539535
# [615]	train-mlogloss:0.421901	test-mlogloss:0.539511
# [616]	train-mlogloss:0.421758	test-mlogloss:0.539495
# [617]	train-mlogloss:0.421544	test-mlogloss:0.539493
# [618]	train-mlogloss:0.421491	test-mlogloss:0.539488
# [619]	train-mlogloss:0.421374	test-mlogloss:0.539494
# [620]	train-mlogloss:0.421149	test-mlogloss:0.53945
# [621]	train-mlogloss:0.42101	test-mlogloss:0.539454
# [622]	train-mlogloss:0.42097	test-mlogloss:0.539447
# [623]	train-mlogloss:0.420705	test-mlogloss:0.539392
# [624]	train-mlogloss:0.420546	test-mlogloss:0.53939
# [625]	train-mlogloss:0.420431	test-mlogloss:0.53938
# [626]	train-mlogloss:0.420267	test-mlogloss:0.539337
# [627]	train-mlogloss:0.420188	test-mlogloss:0.539337
# [628]	train-mlogloss:0.419977	test-mlogloss:0.539272
# [629]	train-mlogloss:0.419823	test-mlogloss:0.539265
# [630]	train-mlogloss:0.4196	test-mlogloss:0.539219
# [631]	train-mlogloss:0.419436	test-mlogloss:0.539172
# [632]	train-mlogloss:0.419308	test-mlogloss:0.539146
# [633]	train-mlogloss:0.419273	test-mlogloss:0.539143
# [634]	train-mlogloss:0.419154	test-mlogloss:0.539121
# [635]	train-mlogloss:0.418992	test-mlogloss:0.539114
# [636]	train-mlogloss:0.4188	test-mlogloss:0.539104
# [637]	train-mlogloss:0.418666	test-mlogloss:0.539079
# [638]	train-mlogloss:0.418435	test-mlogloss:0.53901
# [639]	train-mlogloss:0.418251	test-mlogloss:0.538976
# [640]	train-mlogloss:0.418133	test-mlogloss:0.538936
# [641]	train-mlogloss:0.417981	test-mlogloss:0.538891
# [642]	train-mlogloss:0.417838	test-mlogloss:0.538851
# [643]	train-mlogloss:0.417658	test-mlogloss:0.538849
# [644]	train-mlogloss:0.417495	test-mlogloss:0.538837
# [645]	train-mlogloss:0.417332	test-mlogloss:0.538784
# [646]	train-mlogloss:0.417143	test-mlogloss:0.538787
# [647]	train-mlogloss:0.417029	test-mlogloss:0.538793
# [648]	train-mlogloss:0.416898	test-mlogloss:0.53878
# [649]	train-mlogloss:0.416775	test-mlogloss:0.538773
# [650]	train-mlogloss:0.416607	test-mlogloss:0.538768
# [651]	train-mlogloss:0.416444	test-mlogloss:0.538773
# [652]	train-mlogloss:0.416209	test-mlogloss:0.538735
# [653]	train-mlogloss:0.41607	test-mlogloss:0.538707
# [654]	train-mlogloss:0.416	test-mlogloss:0.5387
# [655]	train-mlogloss:0.415835	test-mlogloss:0.538633
# [656]	train-mlogloss:0.415798	test-mlogloss:0.538632
# [657]	train-mlogloss:0.415521	test-mlogloss:0.538558
# [658]	train-mlogloss:0.415305	test-mlogloss:0.53857
# [659]	train-mlogloss:0.415161	test-mlogloss:0.53853
# [660]	train-mlogloss:0.414954	test-mlogloss:0.53846
# [661]	train-mlogloss:0.414892	test-mlogloss:0.53846
# [662]	train-mlogloss:0.414764	test-mlogloss:0.538461
# [663]	train-mlogloss:0.414642	test-mlogloss:0.538474
# [664]	train-mlogloss:0.414452	test-mlogloss:0.538463
# [665]	train-mlogloss:0.414277	test-mlogloss:0.538438
# [666]	train-mlogloss:0.414177	test-mlogloss:0.538432
# [667]	train-mlogloss:0.413974	test-mlogloss:0.538424
# [668]	train-mlogloss:0.413837	test-mlogloss:0.538418
# [669]	train-mlogloss:0.413755	test-mlogloss:0.538438
# [670]	train-mlogloss:0.413603	test-mlogloss:0.538422
# [671]	train-mlogloss:0.413471	test-mlogloss:0.538364
# [672]	train-mlogloss:0.413336	test-mlogloss:0.538355
# [673]	train-mlogloss:0.413203	test-mlogloss:0.538345
# [674]	train-mlogloss:0.413047	test-mlogloss:0.538296
# [675]	train-mlogloss:0.412897	test-mlogloss:0.538308
# [676]	train-mlogloss:0.412761	test-mlogloss:0.538302
# [677]	train-mlogloss:0.412731	test-mlogloss:0.53829
# [678]	train-mlogloss:0.412531	test-mlogloss:0.538285
# [679]	train-mlogloss:0.412417	test-mlogloss:0.538261
# [680]	train-mlogloss:0.412294	test-mlogloss:0.53824
# [681]	train-mlogloss:0.412071	test-mlogloss:0.538223
# [682]	train-mlogloss:0.411994	test-mlogloss:0.53822
# [683]	train-mlogloss:0.41192	test-mlogloss:0.538218
# [684]	train-mlogloss:0.411759	test-mlogloss:0.538199
# [685]	train-mlogloss:0.411563	test-mlogloss:0.538156
# [686]	train-mlogloss:0.411402	test-mlogloss:0.538141
# [687]	train-mlogloss:0.411273	test-mlogloss:0.538159
# [688]	train-mlogloss:0.41111	test-mlogloss:0.538116
# [689]	train-mlogloss:0.41102	test-mlogloss:0.538096
# [690]	train-mlogloss:0.410874	test-mlogloss:0.538081
# [691]	train-mlogloss:0.410693	test-mlogloss:0.538065
# [692]	train-mlogloss:0.410606	test-mlogloss:0.53805
# [693]	train-mlogloss:0.410462	test-mlogloss:0.538051
# [694]	train-mlogloss:0.410318	test-mlogloss:0.538045
# [695]	train-mlogloss:0.410122	test-mlogloss:0.53799
# [696]	train-mlogloss:0.40991	test-mlogloss:0.537951
# [697]	train-mlogloss:0.40972	test-mlogloss:0.537948
# [698]	train-mlogloss:0.409527	test-mlogloss:0.537921
# [699]	train-mlogloss:0.409373	test-mlogloss:0.537875
# [700]	train-mlogloss:0.409262	test-mlogloss:0.537875
# [701]	train-mlogloss:0.409108	test-mlogloss:0.53788
# [702]	train-mlogloss:0.40889	test-mlogloss:0.537829
# [703]	train-mlogloss:0.40871	test-mlogloss:0.537799
# [704]	train-mlogloss:0.408554	test-mlogloss:0.537797
# [705]	train-mlogloss:0.408432	test-mlogloss:0.537817
# [706]	train-mlogloss:0.408223	test-mlogloss:0.537807
# [707]	train-mlogloss:0.408115	test-mlogloss:0.537814
# [708]	train-mlogloss:0.408115	test-mlogloss:0.537814
# [709]	train-mlogloss:0.407929	test-mlogloss:0.537834
# [710]	train-mlogloss:0.407726	test-mlogloss:0.537796
# [711]	train-mlogloss:0.407605	test-mlogloss:0.537783
# [712]	train-mlogloss:0.40747	test-mlogloss:0.537774
# [713]	train-mlogloss:0.407348	test-mlogloss:0.537765
# [714]	train-mlogloss:0.407258	test-mlogloss:0.537758
# [715]	train-mlogloss:0.407111	test-mlogloss:0.537787
# [716]	train-mlogloss:0.406999	test-mlogloss:0.537783
# [717]	train-mlogloss:0.406837	test-mlogloss:0.537755
# [718]	train-mlogloss:0.406646	test-mlogloss:0.537728
# [719]	train-mlogloss:0.40646	test-mlogloss:0.537764
# [720]	train-mlogloss:0.406348	test-mlogloss:0.537764
# [721]	train-mlogloss:0.406267	test-mlogloss:0.537744
# [722]	train-mlogloss:0.406133	test-mlogloss:0.537738
# [723]	train-mlogloss:0.405981	test-mlogloss:0.537733
# [724]	train-mlogloss:0.405889	test-mlogloss:0.537726
# [725]	train-mlogloss:0.405689	test-mlogloss:0.537673
# [726]	train-mlogloss:0.405562	test-mlogloss:0.537645
# [727]	train-mlogloss:0.405374	test-mlogloss:0.537605
# [728]	train-mlogloss:0.405286	test-mlogloss:0.537596
# [729]	train-mlogloss:0.405178	test-mlogloss:0.537578
# [730]	train-mlogloss:0.40499	test-mlogloss:0.537578
# [731]	train-mlogloss:0.404837	test-mlogloss:0.537535
# [732]	train-mlogloss:0.404677	test-mlogloss:0.537499
# [733]	train-mlogloss:0.404442	test-mlogloss:0.537481
# [734]	train-mlogloss:0.404346	test-mlogloss:0.53747
# [735]	train-mlogloss:0.40414	test-mlogloss:0.537448
# [736]	train-mlogloss:0.403955	test-mlogloss:0.537415
# [737]	train-mlogloss:0.403803	test-mlogloss:0.537422
# [738]	train-mlogloss:0.403656	test-mlogloss:0.537405
# [739]	train-mlogloss:0.403477	test-mlogloss:0.53741
# [740]	train-mlogloss:0.403381	test-mlogloss:0.537407
# [741]	train-mlogloss:0.403265	test-mlogloss:0.537388
# [742]	train-mlogloss:0.403085	test-mlogloss:0.537409
# [743]	train-mlogloss:0.402982	test-mlogloss:0.537404
# [744]	train-mlogloss:0.402834	test-mlogloss:0.537399
# [745]	train-mlogloss:0.402786	test-mlogloss:0.537405
# [746]	train-mlogloss:0.402651	test-mlogloss:0.537405
# [747]	train-mlogloss:0.402548	test-mlogloss:0.537394
# [748]	train-mlogloss:0.402355	test-mlogloss:0.537383
# [749]	train-mlogloss:0.402242	test-mlogloss:0.537368
# [750]	train-mlogloss:0.402087	test-mlogloss:0.537386
# [751]	train-mlogloss:0.401891	test-mlogloss:0.537382
# [752]	train-mlogloss:0.401724	test-mlogloss:0.537358
# [753]	train-mlogloss:0.401602	test-mlogloss:0.537327
# [754]	train-mlogloss:0.40153	test-mlogloss:0.537323
# [755]	train-mlogloss:0.401387	test-mlogloss:0.5373
# [756]	train-mlogloss:0.401294	test-mlogloss:0.537302
# [757]	train-mlogloss:0.401099	test-mlogloss:0.537254
# [758]	train-mlogloss:0.400906	test-mlogloss:0.537265
# [759]	train-mlogloss:0.400823	test-mlogloss:0.537231
# [760]	train-mlogloss:0.400689	test-mlogloss:0.53723
# [761]	train-mlogloss:0.400614	test-mlogloss:0.537236
# [762]	train-mlogloss:0.400425	test-mlogloss:0.537214
# [763]	train-mlogloss:0.400329	test-mlogloss:0.537169
# [764]	train-mlogloss:0.400255	test-mlogloss:0.537192
# [765]	train-mlogloss:0.400053	test-mlogloss:0.537194
# [766]	train-mlogloss:0.399897	test-mlogloss:0.537142
# [767]	train-mlogloss:0.399693	test-mlogloss:0.537122
# [768]	train-mlogloss:0.399567	test-mlogloss:0.537112
# [769]	train-mlogloss:0.399402	test-mlogloss:0.537112
# [770]	train-mlogloss:0.399214	test-mlogloss:0.537116
# [771]	train-mlogloss:0.399019	test-mlogloss:0.537087
# [772]	train-mlogloss:0.398858	test-mlogloss:0.537085
# [773]	train-mlogloss:0.398658	test-mlogloss:0.537055
# [774]	train-mlogloss:0.398477	test-mlogloss:0.537013
# [775]	train-mlogloss:0.398326	test-mlogloss:0.536992
# [776]	train-mlogloss:0.398197	test-mlogloss:0.53695
# [777]	train-mlogloss:0.39797	test-mlogloss:0.53695
# [778]	train-mlogloss:0.39788	test-mlogloss:0.536954
# [779]	train-mlogloss:0.397728	test-mlogloss:0.536914
# [780]	train-mlogloss:0.397607	test-mlogloss:0.5369
# [781]	train-mlogloss:0.397525	test-mlogloss:0.536871
# [782]	train-mlogloss:0.397393	test-mlogloss:0.536862
# [783]	train-mlogloss:0.397241	test-mlogloss:0.536823
# [784]	train-mlogloss:0.397058	test-mlogloss:0.536823
# [785]	train-mlogloss:0.396968	test-mlogloss:0.536826
# [786]	train-mlogloss:0.396752	test-mlogloss:0.536787
# [787]	train-mlogloss:0.396663	test-mlogloss:0.536729
# [788]	train-mlogloss:0.396544	test-mlogloss:0.536726
# [789]	train-mlogloss:0.396369	test-mlogloss:0.536716
# [790]	train-mlogloss:0.396266	test-mlogloss:0.536694
# [791]	train-mlogloss:0.396172	test-mlogloss:0.536671
# [792]	train-mlogloss:0.396032	test-mlogloss:0.536674
# [793]	train-mlogloss:0.395992	test-mlogloss:0.536661
# [794]	train-mlogloss:0.395874	test-mlogloss:0.536669
# [795]	train-mlogloss:0.395766	test-mlogloss:0.536692
# [796]	train-mlogloss:0.395563	test-mlogloss:0.53671
# [797]	train-mlogloss:0.395437	test-mlogloss:0.536719
# [798]	train-mlogloss:0.395267	test-mlogloss:0.536695
# [799]	train-mlogloss:0.395185	test-mlogloss:0.536669
# [800]	train-mlogloss:0.395038	test-mlogloss:0.536698
# [801]	train-mlogloss:0.394929	test-mlogloss:0.53667
# [802]	train-mlogloss:0.394709	test-mlogloss:0.536682
# [803]	train-mlogloss:0.394582	test-mlogloss:0.53669
# [804]	train-mlogloss:0.394403	test-mlogloss:0.536708
# [805]	train-mlogloss:0.394235	test-mlogloss:0.536712
# [806]	train-mlogloss:0.394122	test-mlogloss:0.536701
# [807]	train-mlogloss:0.393948	test-mlogloss:0.536686
# [808]	train-mlogloss:0.393854	test-mlogloss:0.536662
# [809]	train-mlogloss:0.393698	test-mlogloss:0.536643
# [810]	train-mlogloss:0.393578	test-mlogloss:0.536642
# [811]	train-mlogloss:0.393497	test-mlogloss:0.536645
# [812]	train-mlogloss:0.393347	test-mlogloss:0.536607
# [813]	train-mlogloss:0.393213	test-mlogloss:0.536583
# [814]	train-mlogloss:0.393111	test-mlogloss:0.536553
# [815]	train-mlogloss:0.392976	test-mlogloss:0.536552
# [816]	train-mlogloss:0.392855	test-mlogloss:0.536564
# [817]	train-mlogloss:0.392679	test-mlogloss:0.536546
# [818]	train-mlogloss:0.392528	test-mlogloss:0.536541
# [819]	train-mlogloss:0.392429	test-mlogloss:0.536543
# [820]	train-mlogloss:0.392316	test-mlogloss:0.536542
# [821]	train-mlogloss:0.392193	test-mlogloss:0.536551
# [822]	train-mlogloss:0.392028	test-mlogloss:0.536544
# [823]	train-mlogloss:0.391878	test-mlogloss:0.536522
# [824]	train-mlogloss:0.391791	test-mlogloss:0.536514
# [825]	train-mlogloss:0.391601	test-mlogloss:0.536491
# [826]	train-mlogloss:0.391504	test-mlogloss:0.536463
# [827]	train-mlogloss:0.391379	test-mlogloss:0.536438
# [828]	train-mlogloss:0.39121	test-mlogloss:0.536421
# [829]	train-mlogloss:0.391086	test-mlogloss:0.536423
# [830]	train-mlogloss:0.390909	test-mlogloss:0.536409
# [831]	train-mlogloss:0.390762	test-mlogloss:0.536424
# [832]	train-mlogloss:0.390651	test-mlogloss:0.536413
# [833]	train-mlogloss:0.390484	test-mlogloss:0.53641
# [834]	train-mlogloss:0.390263	test-mlogloss:0.536446
# [835]	train-mlogloss:0.390133	test-mlogloss:0.536455
# [836]	train-mlogloss:0.389992	test-mlogloss:0.536408
# [837]	train-mlogloss:0.389876	test-mlogloss:0.536398
# [838]	train-mlogloss:0.389782	test-mlogloss:0.536395
# [839]	train-mlogloss:0.389628	test-mlogloss:0.536391
# [840]	train-mlogloss:0.389485	test-mlogloss:0.536348
# [841]	train-mlogloss:0.389367	test-mlogloss:0.536334
# [842]	train-mlogloss:0.389207	test-mlogloss:0.536343
# [843]	train-mlogloss:0.389083	test-mlogloss:0.536333
# [844]	train-mlogloss:0.388967	test-mlogloss:0.536326
# [845]	train-mlogloss:0.38892	test-mlogloss:0.536336
# [846]	train-mlogloss:0.388824	test-mlogloss:0.536332
# [847]	train-mlogloss:0.388661	test-mlogloss:0.536328
# [848]	train-mlogloss:0.388541	test-mlogloss:0.536302
# [849]	train-mlogloss:0.388394	test-mlogloss:0.536327
# [850]	train-mlogloss:0.388244	test-mlogloss:0.536326
# [851]	train-mlogloss:0.388116	test-mlogloss:0.536347
# [852]	train-mlogloss:0.387991	test-mlogloss:0.536355
# [853]	train-mlogloss:0.387864	test-mlogloss:0.536337
# [854]	train-mlogloss:0.387749	test-mlogloss:0.536327
# [855]	train-mlogloss:0.387641	test-mlogloss:0.536326
# [856]	train-mlogloss:0.387516	test-mlogloss:0.536291
# [857]	train-mlogloss:0.387359	test-mlogloss:0.536284
# [858]	train-mlogloss:0.387244	test-mlogloss:0.536297
# [859]	train-mlogloss:0.387054	test-mlogloss:0.536261
# [860]	train-mlogloss:0.386972	test-mlogloss:0.53627
# [861]	train-mlogloss:0.386842	test-mlogloss:0.536235
# [862]	train-mlogloss:0.386673	test-mlogloss:0.536182
# [863]	train-mlogloss:0.386543	test-mlogloss:0.53618
# [864]	train-mlogloss:0.386461	test-mlogloss:0.536163
# [865]	train-mlogloss:0.386366	test-mlogloss:0.536169
# [866]	train-mlogloss:0.386283	test-mlogloss:0.536161
# [867]	train-mlogloss:0.386089	test-mlogloss:0.536157
# [868]	train-mlogloss:0.385927	test-mlogloss:0.536157
# [869]	train-mlogloss:0.385769	test-mlogloss:0.53614
# [870]	train-mlogloss:0.385592	test-mlogloss:0.536141
# [871]	train-mlogloss:0.385445	test-mlogloss:0.53615
# [872]	train-mlogloss:0.385345	test-mlogloss:0.536137
# [873]	train-mlogloss:0.385202	test-mlogloss:0.53612
# [874]	train-mlogloss:0.385084	test-mlogloss:0.536124
# [875]	train-mlogloss:0.385039	test-mlogloss:0.536108
# [876]	train-mlogloss:0.384937	test-mlogloss:0.536121
# [877]	train-mlogloss:0.384776	test-mlogloss:0.53612
# [878]	train-mlogloss:0.384694	test-mlogloss:0.536108
# [879]	train-mlogloss:0.38451	test-mlogloss:0.536075
# [880]	train-mlogloss:0.384361	test-mlogloss:0.536043
# [881]	train-mlogloss:0.384211	test-mlogloss:0.536007
# [882]	train-mlogloss:0.384087	test-mlogloss:0.53599
# [883]	train-mlogloss:0.38393	test-mlogloss:0.535955
# [884]	train-mlogloss:0.383815	test-mlogloss:0.535949
# [885]	train-mlogloss:0.383654	test-mlogloss:0.53596
# [886]	train-mlogloss:0.383571	test-mlogloss:0.535985
# [887]	train-mlogloss:0.383501	test-mlogloss:0.535991
# [888]	train-mlogloss:0.383347	test-mlogloss:0.535987
# [889]	train-mlogloss:0.383208	test-mlogloss:0.535972
# [890]	train-mlogloss:0.383058	test-mlogloss:0.535947
# [891]	train-mlogloss:0.382928	test-mlogloss:0.535928
# [892]	train-mlogloss:0.382745	test-mlogloss:0.535914
# [893]	train-mlogloss:0.382556	test-mlogloss:0.535863
# [894]	train-mlogloss:0.382469	test-mlogloss:0.535854
# [895]	train-mlogloss:0.382284	test-mlogloss:0.53585
# [896]	train-mlogloss:0.382188	test-mlogloss:0.535877
# [897]	train-mlogloss:0.382094	test-mlogloss:0.535891
# [898]	train-mlogloss:0.38196	test-mlogloss:0.535906
# [899]	train-mlogloss:0.381784	test-mlogloss:0.535891
# [900]	train-mlogloss:0.381646	test-mlogloss:0.535885
# [901]	train-mlogloss:0.381476	test-mlogloss:0.535875
# [902]	train-mlogloss:0.381356	test-mlogloss:0.535871
# [903]	train-mlogloss:0.381164	test-mlogloss:0.535883
# [904]	train-mlogloss:0.38101	test-mlogloss:0.535844
# [905]	train-mlogloss:0.380925	test-mlogloss:0.535872
# [906]	train-mlogloss:0.380767	test-mlogloss:0.535888
# [907]	train-mlogloss:0.380626	test-mlogloss:0.535855
# [908]	train-mlogloss:0.380547	test-mlogloss:0.535867
# [909]	train-mlogloss:0.380429	test-mlogloss:0.535864
# [910]	train-mlogloss:0.380327	test-mlogloss:0.535862
# [911]	train-mlogloss:0.380159	test-mlogloss:0.535837
# [912]	train-mlogloss:0.380055	test-mlogloss:0.535851
# [913]	train-mlogloss:0.379905	test-mlogloss:0.53581
# [914]	train-mlogloss:0.379766	test-mlogloss:0.535786
# [915]	train-mlogloss:0.379645	test-mlogloss:0.535767
# [916]	train-mlogloss:0.379473	test-mlogloss:0.535751
# [917]	train-mlogloss:0.379366	test-mlogloss:0.535776
# [918]	train-mlogloss:0.379206	test-mlogloss:0.535761
# [919]	train-mlogloss:0.379058	test-mlogloss:0.535783
# [920]	train-mlogloss:0.378891	test-mlogloss:0.535776
# [921]	train-mlogloss:0.37876	test-mlogloss:0.535758
# [922]	train-mlogloss:0.378641	test-mlogloss:0.535769
# [923]	train-mlogloss:0.378468	test-mlogloss:0.535774
# [924]	train-mlogloss:0.378364	test-mlogloss:0.535759
# [925]	train-mlogloss:0.378225	test-mlogloss:0.535736
# [926]	train-mlogloss:0.378034	test-mlogloss:0.535721
# [927]	train-mlogloss:0.377879	test-mlogloss:0.535677
# [928]	train-mlogloss:0.377702	test-mlogloss:0.535685
# [929]	train-mlogloss:0.377542	test-mlogloss:0.535688
# [930]	train-mlogloss:0.377371	test-mlogloss:0.535677
# [931]	train-mlogloss:0.377191	test-mlogloss:0.535683
# [932]	train-mlogloss:0.37705	test-mlogloss:0.535704
# [933]	train-mlogloss:0.376938	test-mlogloss:0.535711
# [934]	train-mlogloss:0.376799	test-mlogloss:0.535731
# [935]	train-mlogloss:0.376649	test-mlogloss:0.535704
# [936]	train-mlogloss:0.376588	test-mlogloss:0.535695
# [937]	train-mlogloss:0.376462	test-mlogloss:0.535706
# [938]	train-mlogloss:0.376354	test-mlogloss:0.535715
# [939]	train-mlogloss:0.376291	test-mlogloss:0.535715
# [940]	train-mlogloss:0.376173	test-mlogloss:0.535689
# [941]	train-mlogloss:0.376132	test-mlogloss:0.535687
# [942]	train-mlogloss:0.376045	test-mlogloss:0.535698
# [943]	train-mlogloss:0.375907	test-mlogloss:0.535704
# [944]	train-mlogloss:0.375769	test-mlogloss:0.535669
# [945]	train-mlogloss:0.37567	test-mlogloss:0.535678
# [946]	train-mlogloss:0.375617	test-mlogloss:0.535661
# [947]	train-mlogloss:0.37548	test-mlogloss:0.535644
# [948]	train-mlogloss:0.375408	test-mlogloss:0.535663
# [949]	train-mlogloss:0.375243	test-mlogloss:0.535652
# [950]	train-mlogloss:0.375149	test-mlogloss:0.535621
# [951]	train-mlogloss:0.374999	test-mlogloss:0.535607
# [952]	train-mlogloss:0.374805	test-mlogloss:0.535571
# [953]	train-mlogloss:0.374652	test-mlogloss:0.535598
# [954]	train-mlogloss:0.374536	test-mlogloss:0.535593
# [955]	train-mlogloss:0.37439	test-mlogloss:0.535587
# [956]	train-mlogloss:0.374249	test-mlogloss:0.535577
# [957]	train-mlogloss:0.374075	test-mlogloss:0.535613
# [958]	train-mlogloss:0.374039	test-mlogloss:0.535609
# [959]	train-mlogloss:0.373892	test-mlogloss:0.535576
# [960]	train-mlogloss:0.373763	test-mlogloss:0.535534
# [961]	train-mlogloss:0.373675	test-mlogloss:0.53555
# [962]	train-mlogloss:0.373606	test-mlogloss:0.535532
# [963]	train-mlogloss:0.373454	test-mlogloss:0.535534
# [964]	train-mlogloss:0.373324	test-mlogloss:0.535484
# [965]	train-mlogloss:0.373288	test-mlogloss:0.535499
# [966]	train-mlogloss:0.373144	test-mlogloss:0.535485
# [967]	train-mlogloss:0.373002	test-mlogloss:0.535509
# [968]	train-mlogloss:0.372874	test-mlogloss:0.535452
# [969]	train-mlogloss:0.372735	test-mlogloss:0.535425
# [970]	train-mlogloss:0.372593	test-mlogloss:0.535423
# [971]	train-mlogloss:0.372505	test-mlogloss:0.535379
# [972]	train-mlogloss:0.372373	test-mlogloss:0.535372
# [973]	train-mlogloss:0.372275	test-mlogloss:0.535381
# [974]	train-mlogloss:0.372135	test-mlogloss:0.535356
# [975]	train-mlogloss:0.371999	test-mlogloss:0.535334
# [976]	train-mlogloss:0.371927	test-mlogloss:0.53532
# [977]	train-mlogloss:0.371797	test-mlogloss:0.535294
# [978]	train-mlogloss:0.371651	test-mlogloss:0.535317
# [979]	train-mlogloss:0.371519	test-mlogloss:0.535303
# [980]	train-mlogloss:0.371439	test-mlogloss:0.535286
# [981]	train-mlogloss:0.371336	test-mlogloss:0.535266
# [982]	train-mlogloss:0.371283	test-mlogloss:0.535259
# [983]	train-mlogloss:0.37116	test-mlogloss:0.535253
# [984]	train-mlogloss:0.371061	test-mlogloss:0.53522
# [985]	train-mlogloss:0.37084	test-mlogloss:0.535191
# [986]	train-mlogloss:0.370708	test-mlogloss:0.535177
# [987]	train-mlogloss:0.370625	test-mlogloss:0.53519
# [988]	train-mlogloss:0.370553	test-mlogloss:0.535172
# [989]	train-mlogloss:0.370445	test-mlogloss:0.535165
# [990]	train-mlogloss:0.370316	test-mlogloss:0.535143
# [991]	train-mlogloss:0.370196	test-mlogloss:0.535131
# [992]	train-mlogloss:0.370059	test-mlogloss:0.535134
# [993]	train-mlogloss:0.369866	test-mlogloss:0.535123
# [994]	train-mlogloss:0.369778	test-mlogloss:0.53512
# [995]	train-mlogloss:0.369651	test-mlogloss:0.535115
# [996]	train-mlogloss:0.369503	test-mlogloss:0.535078
# [997]	train-mlogloss:0.369473	test-mlogloss:0.535087
# [998]	train-mlogloss:0.369377	test-mlogloss:0.535083
# [999]	train-mlogloss:0.369296	test-mlogloss:0.535092
# [0.53509169050363514]

# %%
preds, model = runXGB(train_X, train_y, test_X, num_rounds=1000)
out_df = pd.DataFrame(preds)
out_df.columns = ["high", "medium", "low"]
out_df["listing_id"] = test_df.listing_id.values
out_df.to_csv("xgb_starter2.csv", index=False)
